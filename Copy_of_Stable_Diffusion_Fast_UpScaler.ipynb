# %% [markdown]
# <a href="https://colab.research.google.com/github/plaban1981/stable_diffusion/blob/main/Copy_of_Stable_Diffusion_Fast_UpScaler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/huggingface/diffusers.git -q
# !pip install transformers accelerate scipy safetensors -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 13.1 MB/s eta 0:00:00
#   Building wheel for diffusers (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 96.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 24.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 49.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 105.5 MB/s eta 0:00:00

# %%
from diffusers import StableDiffusionLatentUpscalePipeline, StableDiffusionPipeline
import torch

# %%
#pipeline = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", torch_dtype=torch.float16)

pipeline = StableDiffusionPipeline.from_pretrained("wavymulder/Analog-Diffusion", torch_dtype=torch.float16)
pipeline.to("cuda")
# Out:
# Downloading (…)ain/model_index.json:   0%|          | 0.00/582 [00:00<?, ?B/s]
# text_encoder/model.safetensors not found
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/518 [00:00<?, ?B/s]
# Downloading (…)cheduler_config.json:   0%|          | 0.00/346 [00:00<?, ?B/s]
# Downloading (…)_checker/config.json:   0%|          | 0.00/4.91k [00:00<?, ?B/s]
# Downloading (…)_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading (…)tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading (…)_pytorch_model.bin";:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading (…)484/unet/config.json:   0%|          | 0.00/877 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading (…)6484/vae/config.json:   0%|          | 0.00/582 [00:00<?, ?B/s]
# Downloading (…)_pytorch_model.bin";:   0%|          | 0.00/335M [00:00<?, ?B/s]
# StableDiffusionPipeline {
#   "_class_name": "StableDiffusionPipeline",
#   "_diffusers_version": "0.13.0.dev0",
#   "feature_extractor": [
#     "transformers",
#     "CLIPImageProcessor"
#   ],
#   "requires_safety_checker": true,
#   "safety_checker": [
#     "stable_diffusion",
#     "StableDiffusionSafetyChecker"
#   ],
#   "scheduler": [
#     "diffusers",
#     "PNDMScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
upscaler = StableDiffusionLatentUpscalePipeline.from_pretrained("stabilityai/sd-x2-latent-upscaler", torch_dtype=torch.float16)
upscaler.to("cuda")
# Out:
# Downloading (…)ain/model_index.json:   0%|          | 0.00/408 [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading (…)ca0/unet/config.json:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# Downloading (…)tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading (…)_encoder/config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading (…)cheduler_config.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/831 [00:00<?, ?B/s]
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading (…)_pytorch_model.bin";:   0%|          | 0.00/1.49G [00:00<?, ?B/s]
# Downloading (…)_pytorch_model.bin";:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Downloading (…)bca0/vae/config.json:   0%|          | 0.00/653 [00:00<?, ?B/s]
# StableDiffusionLatentUpscalePipeline {
#   "_class_name": "StableDiffusionLatentUpscalePipeline",
#   "_diffusers_version": "0.13.0.dev0",
#   "scheduler": [
#     "diffusers",
#     "EulerDiscreteScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
prompt = "analog style close up photo portrait of a young chinese girl"
generator = torch.manual_seed(1191447504)

# %%
low_res_latents = pipeline(prompt, generator=generator, output_type="latent", num_inference_steps = 30, guidance_scale = 7).images
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
upscaled_image = upscaler(
    prompt=prompt,
    image=low_res_latents,
    num_inference_steps=30,
    guidance_scale=0,
    generator=generator,
).images[0]
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# Low Res Image

# %%
with torch.no_grad():
    image = pipeline.decode_latents(low_res_latents)
image = pipeline.numpy_to_pil(image)[0]

image.save("low_res_image.png")

# %% [markdown]
# HD Image

# %%
upscaled_image.save("high_res_1024.png")

# %% [markdown]
# Display Final Results

# %%
from IPython.display import Image
Image("low_res_image.png")

# %%
from IPython.display import Image
Image("high_res_1024.png")
